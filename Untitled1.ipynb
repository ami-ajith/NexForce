# %% [markdown]
# <a href="https://colab.research.google.com/github/ami-ajith/NexForce/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-d5a26bf5-6165-4d07-af6b-1b3b294ebc99" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d5a26bf5-6165-4d07-af6b-1b3b294ebc99">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from io import BytesIO
import io
df=pd.read_excel(io.BytesIO(uploaded['SOCR-HeightWeight_.xlsx']))
df
# Out:
#        Index  Height(Inches)  Weight(Pounds)
# 0          1        65.78331        112.9925
# 1          2        71.51521        136.4873
# 2          3        69.39874        153.0269
# 3          4        68.21660        142.3354
# 4          5        67.78781        144.2971
# ...      ...             ...             ...
# 24995  24996        69.50215        118.0312
# 24996  24997        64.54826        120.1932
# 24997  24998        64.69855        118.2655
# 24998  24999        67.52918        132.2682
# 24999  25000        68.87761        124.8742
#
# [25000 rows x 3 columns]

# %%
import pandas as pd
from statistics import mean, median, mode
path='/content/gdrive/MyDrive/dataset/SOCR-HeightWeight_.xlsx'
data=pd.read_excel(path)

data_height=data['Height(Inches)']
data_weight=data['Weight(Pounds)']

#To find Mean
height_mean=mean(data_height)
weight_mean=mean(data_weight)

#To find median
height_median=median(data_height)
weight_median=median(data_weight)

#to find mode
height_mode=mode(data_height)
weight_mode=mode(data_weight)

print("*Height*")
print("mean:",height_mean)
print("median:",height_median)
print("mode:",height_mode)
# Out:
# *Height*
# mean: 67.9931135968
# median: 67.9957
# mode: 70.04724
